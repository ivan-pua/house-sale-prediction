# %% [markdown]
# # Predict which house is qualified for sell
#
# - add scaling?
# - Ml/Dl to predict price

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("Assignment-HousingDataset.csv")

# %% [markdown]
# ## Remove categorical features if there is a number

# %%
cols_to_drop = ['row ID',
                'HEAT_D',
                'STYLE_D',
                'STRUCT_D',
                'GRADE_D',
                'CNDTN_D',
                'EXTWALL_D',
                'ROOF_D',
                'INTWALL_D',
                'GIS_LAST_MOD_DTTM',
               ]

df.drop(columns= cols_to_drop,
        inplace=True)

# %%
# Find out how many missing values for column
missing_vals = df.isna().sum()
missing_vals
# Out:
# BATHRM           20
# HF_BATHRM        21
# HEAT             20
# AC               20
# NUM_UNITS        20
# ROOMS            32
# BEDRM            24
# AYB              10
# YR_RMDL       40473
# EYB               0
# STORIES          52
# SALEDATE          0
# PRICE         13506
# SALE_NUM          0
# GBA               0
# BLDG_NUM          0
# STYLE            20
# STRUCT           20
# GRADE            20
# CNDTN            20
# EXTWALL          20
# ROOF             20
# INTWALL          20
# KITCHENS         21
# FIREPLACES       21
# USECODE           0
# LANDAREA          0
# QUALIFIED         0
# dtype: int64

# %%
# miss_array = np.array(missing_vals.values)
# np.savetxt('missing_vals.csv', miss_array)

# %%
df
# Out:
#        BATHRM  HF_BATHRM  HEAT AC  NUM_UNITS  ROOMS  BEDRM     AYB  YR_RMDL  \
# 0         3.0        1.0   7.0  Y        2.0   11.0    5.0  1898.0   2007.0
# 1         3.0        1.0  13.0  Y        2.0    9.0    5.0  1910.0   2009.0
# 2         2.0        1.0   7.0  Y        1.0   11.0    3.0  1913.0   2012.0
# 3         3.0        2.0  13.0  Y        1.0   10.0    5.0  1913.0      NaN
# 4         3.0        1.0   7.0  Y        2.0    7.0    3.0  1908.0   2008.0
# ...       ...        ...   ... ..        ...    ...    ...     ...      ...
# 75002     2.0        0.0   7.0  Y        2.0   10.0    4.0  1953.0      NaN
# 75003     2.0        0.0   1.0  N        2.0    8.0    4.0  1953.0      NaN
# 75004     2.0        0.0   1.0  N        2.0   10.0    5.0  1953.0      NaN
# 75005     2.0        0.0   1.0  N        2.0   10.0    4.0  1953.0      NaN
# 75006     2.0        0.0   1.0  N        2.0   10.0    4.0  1953.0   2017.0
#
#         EYB  ...  GRADE CNDTN  EXTWALL  ROOF  INTWALL  KITCHENS  FIREPLACES  \
# 0      1972  ...    6.0   4.0     14.0   2.0      6.0       2.0         4.0
# 1      1984  ...    6.0   5.0     14.0   2.0      6.0       2.0         4.0
# 2      1985  ...    6.0   4.0     14.0  13.0      6.0       1.0         0.0
# 3      1972  ...    6.0   4.0     14.0   2.0      6.0       1.0         4.0
# 4      1967  ...    4.0   5.0     14.0   2.0      6.0       2.0         1.0
# ...     ...  ...    ...   ...      ...   ...      ...       ...         ...
# 75002  1962  ...    3.0   3.0     14.0   2.0      6.0       2.0         0.0
# 75003  1962  ...    3.0   3.0     14.0   2.0      6.0       2.0         0.0
# 75004  1962  ...    3.0   3.0     14.0   2.0      6.0       2.0         0.0
# 75005  1953  ...    3.0   3.0     14.0   2.0      6.0       2.0         0.0
# 75006  1971  ...    3.0   4.0     14.0   1.0      6.0       2.0         0.0
#
#        USECODE  LANDAREA  QUALIFIED
# 0           24      1680          0
# 1           24      1680          1
# 2           13      2032          0
# 3           11      2196          1
# 4           24      1424          1
# ...        ...       ...        ...
# 75002       23      5872          0
# 75003       23      6337          0
# 75004       23      5348          0
# 75005       23      3466          0
# 75006       23      3046          0
#
# [75007 rows x 28 columns]

# %% [markdown]
# ## Convert Dates to Datetime Format

# %%
df['SALEDATE'] = df['SALEDATE'].map(lambda x: x.split('T', 1)[0])
df['SALEDATE'] = pd.to_datetime(df['SALEDATE'], format='%Y-%m-%d')

# %%
df['SALEDATE'].value_counts()
# Out:
# 1900-01-01    15885
# 1999-04-01      145
# 2001-01-01      132
# 2006-10-12       47
# 2017-05-23       45
#               ...
# 1993-05-14        1
# 1985-01-11        1
# 1994-01-04        1
# 1987-07-28        1
# 1980-09-03        1
# Name: SALEDATE, Length: 6634, dtype: int64

# %% [markdown]
# Option 1: Get bins of decades e.g. 1900-1910 is category 1 and so on
# Option 2: Get the year only, don't care about month and day
#
# Choosing Option 2 for now

# %%
df['SALEDATE_YEAR']= pd.DatetimeIndex(df['SALEDATE']).year

# %%
df.drop(columns=['SALEDATE'], inplace=True)

# %% [markdown]
# ## Convert Y, N to 1, 0 respectively

# %%
replacement ={
    "AC": {"Y":1, "N": 0}
    
}

df = df.replace(replacement)

# %% [markdown]
# ## Missing Values
# ### Price
# WHy? Find out how to get average price
# https://towardsdatascience.com/7-ways-to-handle-missing-values-in-machine-learning-1a6326adf79e ML or DL

# %%
df['PRICE'] = df.groupby(['BATHRM', 
                          'GRADE', 
                          'CNDTN'])['PRICE'].transform(
    lambda grp: grp.fillna(np.mean(grp)))

# %% [markdown]
# ### Year Remodeled
# If no remodelling, give a different class

# %%
df['YR_RMDL'] = df['YR_RMDL'].fillna(0)

# %%
df.isna().sum()
# Out:
# BATHRM           20
# HF_BATHRM        21
# HEAT             20
# AC               20
# NUM_UNITS        20
# ROOMS            32
# BEDRM            24
# AYB              10
# YR_RMDL           0
# EYB               0
# STORIES          52
# PRICE            41
# SALE_NUM          0
# GBA               0
# BLDG_NUM          0
# STYLE            20
# STRUCT           20
# GRADE            20
# CNDTN            20
# EXTWALL          20
# ROOF             20
# INTWALL          20
# KITCHENS         21
# FIREPLACES       21
# USECODE           0
# LANDAREA          0
# QUALIFIED         0
# SALEDATE_YEAR     0
# dtype: int64

# %% [markdown]
# ## Drop all rows with missing values

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## Split Into Train, Validate and Test

# %%
#Train test split 
from sklearn.model_selection import train_test_split
df_y = df.pop("QUALIFIED") 
train_X, test_X, train_y, test_y = train_test_split(df, df_y,
                                                    test_size=0.2,
                                                    random_state=1
                                                   )

# %%
print(train_X.shape)
print(test_X.shape)
print(train_y.shape)
print(test_y.shape)
# Out:
# (59927, 27)
# (14982, 27)
# (59927,)
# (14982,)

# %% [markdown]
# # Creating Model
# ## Decision Tree
# - try different params

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(max_depth=5)
clf = clf.fit(train_X, train_y)

y_pred = clf.predict(test_X)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(test_y, y_pred))
# Out:
# Accuracy: 0.8966760112134562

# %%
feature_cols = df.columns

# %%
# %%time
fig = plt.figure(figsize=(100,80))
_ = tree.plot_tree(clf, 
                   feature_names=feature_cols,  
                   class_names=['0', '1'],
                   filled=True)
# Out:
# CPU times: user 153 ms, sys: 41.9 ms, total: 194 ms
# Wall time: 192 ms

# %%
fig.savefig("decistion_tree.png")

# %% [markdown]
# ## SVM
